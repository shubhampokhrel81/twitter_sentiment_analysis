# %%
import pandas as pd
import numpy as np
import re
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter
from better_profanity import profanity
from textblob import TextBlob 
import nltk
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# scraper = sntwitter.TwitterSearchScraper('#python')
# scraper

# %%
filter_name = 'weather since:2021-02-24 until:2023-02-21 exclude:retweets exclude:replies lang:en'

# since = input('format yyyy-mm-dd or blank') 

# until = input('format yyyy-mm-dd or blank') 

# since_date = '2021-02-24'
# until_date = '2022-02-24'
scraper = sntwitter.TwitterSearchScraper(filter_name)
scraper
tweets = []
n_tweets = 100
for i, tweet in tqdm(enumerate(scraper.get_items()), total = n_tweets):
    data= [
        tweet.id,
        tweet.date,
        tweet.rawContent,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
        tweet.replyCount,
        tweet.lang,
        tweet.user.location
    ]
#     if tweet.lang == 'en':
    tweets.append(data)
    if i > n_tweets:
        break
tweet_df2 = pd.DataFrame(tweets, columns = ['id','datetime','rawcontent','username','likeCount','retweetCount','replyCount','language','location'])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
(tweet_df2['language'] == 'en').count()
# Out:
# 102

# %%
tweet_df2.sample(10)
# Out:
#                       id                  datetime  \
# 69   1627819464594006021 2023-02-20 23:56:18+00:00
# 22   1627820158130565121 2023-02-20 23:59:03+00:00
# 67   1627819502430982150 2023-02-20 23:56:27+00:00
# 54   1627819686472851458 2023-02-20 23:57:11+00:00
# 76   1627819322163830785 2023-02-20 23:55:44+00:00
# 72   1627819384696672256 2023-02-20 23:55:59+00:00
# 73   1627819360113893379 2023-02-20 23:55:53+00:00
# 96   1627819155163435010 2023-02-20 23:55:04+00:00
# 101  1627819128370110465 2023-02-20 23:54:58+00:00
# 87   1627819207269183488 2023-02-20 23:55:17+00:00
#
#                                             rawcontent         username  \
# 69   I need the weather to pick a side because this...       YuneKokoro
# 22   Temp: 7.9C Wind: 0.7 mph, Max Daily Gust: 15.0...      ME17Weather
# 67   Good morning!!! The sun is shining, the weathe...    unholy_tenshi
# 54                   What’s up with this weather 🤦🏻‍♀️         kizsesss
# 76   They always say you bipolar when the weather d...  DineroDaPharaoh
# 72   FINAL Prediction for Tuesday, February 21, 202...  VWeatherWatcher
# 73   Some Häagen-Dazs in the 50 degree weather soun...        jocehope1
# 96   I’m going to NC tomorrow and this is the weath...   bewarethesmirk
# 101  There is a Fire Weather Watch on Tuesday and a...           KCBD11
# 87   Temp: 62.4°F DP: 43.0°F  HtIdx: 62.4°F High to...       KOKTULSA13
#
#      likeCount  retweetCount  replyCount language                     location
# 69          32             0           3       en            The Dark Alleyway
# 22           0             0           0       en                         ME15
# 67           3             0           1       en        They/Them | Ace-Aro 💙
# 54           0             0           0       en        Lipa City, Calabarzon
# 76           0             0           0       en  Everywhere the money is at.
# 72          14             1           2       en    Northeastern Pennsylvania
# 73           0             0           0       en           Gravity’s Rainbow
# 96           0             0           0       en                   Boston, MA
# 101          0             0           0       en                  Lubbock, TX
# 87           0             0           0       en                    Tulsa, OK

# %% [markdown]
# ## Data preprocessing

# %%
# here transforming the datetime to date and removing the original datetime column

# %%
tweet_df = tweet_df2.copy()
tweet_df
# Out:
#                       id                  datetime  \
# 0    1627820372698562570 2023-02-20 23:59:54+00:00
# 1    1627820371607945217 2023-02-20 23:59:54+00:00
# 2    1627820366725894144 2023-02-20 23:59:53+00:00
# 3    1627820355183075328 2023-02-20 23:59:50+00:00
# 4    1627820344923783171 2023-02-20 23:59:48+00:00
# ..                   ...                       ...
# 97   1627819151799767040 2023-02-20 23:55:03+00:00
# 98   1627819146028146693 2023-02-20 23:55:02+00:00
# 99   1627819141544419331 2023-02-20 23:55:01+00:00
# 100  1627819138252001280 2023-02-20 23:55:00+00:00
# 101  1627819128370110465 2023-02-20 23:54:58+00:00
#
#                                             rawcontent         username  \
# 0    Sunset for February 20, 2023 at 05:31PM! Have ...  GallatinWeather
# 1    I guess our govt decided to stop playing whack...  fusion_allusion
# 2    Report at 00:00 \rWind:SW at av. 0mph, max gus...      HBayWeather
# 3    I think I froze half my piercings off in this ...    gymlifeanimal
# 4    Your weather for tomorrow @denverchannel https...    MikeNelson247
# ..                                                 ...              ...
# 97   Weather-Frankston, Australia @ 10:55 Temp-19.1...   frankstonwethr
# 98   Wichita Weather 61F at 5:55 PM, Wind WNW 1 Gus...      SouthWindWX
# 99   Dixon, MO At: 5:55 PM Temp: 57.4°F Visibility:...     dixonweather
# 100  Wind 5 mph ENE. Barometer 1017.71 hPa, Falling...   quarmbyweather
# 101  There is a Fire Weather Watch on Tuesday and a...           KCBD11
#
#      likeCount  retweetCount  replyCount language  \
# 0            0             0           0       en
# 1            0             0           0       en
# 2            0             0           0       en
# 3          197             2          37       en
# 4           17             1           1       en
# ..         ...           ...         ...      ...
# 97           0             0           0       en
# 98           0             0           0       en
# 99           0             0           0       en
# 100          0             0           0       en
# 101          0             0           0       en
#
#                          location
# 0
# 1
# 2    Sunny Herne Bay (the UK one)
# 3           On a beach somewhere
# 4                      Denver, CO
# ..                            ...
# 97
# 98
# 99            Dixon, Missouri USA
# 100                  Huddersfield
# 101                   Lubbock, TX
#
# [102 rows x 9 columns]

# %%
tweet_df.insert(2, 'date', pd.to_datetime(tweet_df['datetime']).dt.strftime('%Y-%m-%d'))

# %%
tweet_df.drop('datetime',axis=1,inplace=True)

# %%
tweet_df
# Out:
#                       id        date  \
# 0    1627820372698562570  2023-02-20
# 1    1627820371607945217  2023-02-20
# 2    1627820366725894144  2023-02-20
# 3    1627820355183075328  2023-02-20
# 4    1627820344923783171  2023-02-20
# ..                   ...         ...
# 97   1627819151799767040  2023-02-20
# 98   1627819146028146693  2023-02-20
# 99   1627819141544419331  2023-02-20
# 100  1627819138252001280  2023-02-20
# 101  1627819128370110465  2023-02-20
#
#                                             rawcontent         username  \
# 0    Sunset for February 20, 2023 at 05:31PM! Have ...  GallatinWeather
# 1    I guess our govt decided to stop playing whack...  fusion_allusion
# 2    Report at 00:00 \rWind:SW at av. 0mph, max gus...      HBayWeather
# 3    I think I froze half my piercings off in this ...    gymlifeanimal
# 4    Your weather for tomorrow @denverchannel https...    MikeNelson247
# ..                                                 ...              ...
# 97   Weather-Frankston, Australia @ 10:55 Temp-19.1...   frankstonwethr
# 98   Wichita Weather 61F at 5:55 PM, Wind WNW 1 Gus...      SouthWindWX
# 99   Dixon, MO At: 5:55 PM Temp: 57.4°F Visibility:...     dixonweather
# 100  Wind 5 mph ENE. Barometer 1017.71 hPa, Falling...   quarmbyweather
# 101  There is a Fire Weather Watch on Tuesday and a...           KCBD11
#
#      likeCount  retweetCount  replyCount language  \
# 0            0             0           0       en
# 1            0             0           0       en
# 2            0             0           0       en
# 3          197             2          37       en
# 4           17             1           1       en
# ..         ...           ...         ...      ...
# 97           0             0           0       en
# 98           0             0           0       en
# 99           0             0           0       en
# 100          0             0           0       en
# 101          0             0           0       en
#
#                          location
# 0
# 1
# 2    Sunny Herne Bay (the UK one)
# 3           On a beach somewhere
# 4                      Denver, CO
# ..                            ...
# 97
# 98
# 99            Dixon, Missouri USA
# 100                  Huddersfield
# 101                   Lubbock, TX
#
# [102 rows x 9 columns]

# %%
tweet_df.to_csv(f"dataset/{'weather'}.csv", index = False)

# %% [markdown]
# ## Import scraped CSV

# %%
# w_df = pd.read_csv(f"dataset/{filter_name}.csv")
w_df = pd.read_csv(f"dataset/{'weather'}.csv")
w_df
# Out:
#                       id        date  \
# 0    1627820372698562570  2023-02-20
# 1    1627820371607945217  2023-02-20
# 2    1627820366725894144  2023-02-20
# 3    1627820355183075328  2023-02-20
# 4    1627820344923783171  2023-02-20
# ..                   ...         ...
# 97   1627819151799767040  2023-02-20
# 98   1627819146028146693  2023-02-20
# 99   1627819141544419331  2023-02-20
# 100  1627819138252001280  2023-02-20
# 101  1627819128370110465  2023-02-20
#
#                                             rawcontent         username  \
# 0    Sunset for February 20, 2023 at 05:31PM! Have ...  GallatinWeather
# 1    I guess our govt decided to stop playing whack...  fusion_allusion
# 2    Report at 00:00 \rWind:SW at av. 0mph, max gus...      HBayWeather
# 3    I think I froze half my piercings off in this ...    gymlifeanimal
# 4    Your weather for tomorrow @denverchannel https...    MikeNelson247
# ..                                                 ...              ...
# 97   Weather-Frankston, Australia @ 10:55 Temp-19.1...   frankstonwethr
# 98   Wichita Weather 61F at 5:55 PM, Wind WNW 1 Gus...      SouthWindWX
# 99   Dixon, MO At: 5:55 PM Temp: 57.4°F Visibility:...     dixonweather
# 100  Wind 5 mph ENE. Barometer 1017.71 hPa, Falling...   quarmbyweather
# 101  There is a Fire Weather Watch on Tuesday and a...           KCBD11
#
#      likeCount  retweetCount  replyCount language  \
# 0            0             0           0       en
# 1            0             0           0       en
# 2            0             0           0       en
# 3          197             2          37       en
# 4           17             1           1       en
# ..         ...           ...         ...      ...
# 97           0             0           0       en
# 98           0             0           0       en
# 99           0             0           0       en
# 100          0             0           0       en
# 101          0             0           0       en
#
#                          location
# 0                             NaN
# 1                             NaN
# 2    Sunny Herne Bay (the UK one)
# 3           On a beach somewhere
# 4                      Denver, CO
# ..                            ...
# 97                            NaN
# 98                            NaN
# 99            Dixon, Missouri USA
# 100                  Huddersfield
# 101                   Lubbock, TX
#
# [102 rows x 9 columns]

# %% [markdown]
# ## Check for null values

# %%
w_df.isnull().sum()
# Out:
# id               0
# date             0
# rawcontent       0
# username         0
# likeCount        0
# retweetCount     0
# replyCount       0
# language         0
# location        22
# dtype: int64

# %% [markdown]
# ## Performing EDA

# %%
w_df.loc[w_df['likeCount']>=10]
# Out:
#                      id        date  \
# 3   1627820355183075328  2023-02-20
# 4   1627820344923783171  2023-02-20
# 10  1627820303844868097  2023-02-20
# 19  1627820184324001792  2023-02-20
# 38  1627819938789441545  2023-02-20
# 40  1627819933492219904  2023-02-20
# 43  1627819909303377920  2023-02-20
# 65  1627819550027939840  2023-02-20
# 69  1627819464594006021  2023-02-20
# 72  1627819384696672256  2023-02-20
# 77  1627819318816964609  2023-02-20
# 79  1627819294250905603  2023-02-20
# 89  1627819200835092481  2023-02-20
# 91  1627819176222986241  2023-02-20
#
#                                            rawcontent         username  \
# 3   I think I froze half my piercings off in this ...    gymlifeanimal
# 4   Your weather for tomorrow @denverchannel https...    MikeNelson247
# 10  Peaceful sunset over Morse after a wonderful M...  MorseLakeWeathe
# 19  Winds increase late Tuesday with gusts to 40 p...    MandyBaileyWX
# 38  Significant coast-to-coast storm will sweep ac...   Beginning22End
# 40  A very strong weather system will produce pote...          JoeKOAT
# 43  Massive #winterstorm. It covers basically the ...          tymetwx
# 65  #goodmorning #Beijing \nwhat a beautiful weath...        ChanJoe18
# 69  I need the weather to pick a side because this...       YuneKokoro
# 72  FINAL Prediction for Tuesday, February 21, 202...  VWeatherWatcher
# 77  this city’s weather has more mood swings than ...   pragunwastaken
# 79  A late February weather system blowing into We...  DougPigsleyKOMO
# 89  #ONStorm #ONwx Good evening! We've got a quick...       IWeatherON
# 91  Some pretty cool folks with neat ideas at Colu...           metCJR
#
#     likeCount  retweetCount  replyCount language                   location
# 3         197             2          37       en      On a beach somewhere
# 4          17             1           1       en                 Denver, CO
# 10         23             0           2       en    Hamilton County Indiana
# 19         10             3           0       en          Philippians 3:7-8
# 38         13             2           5       en       Rumble: pray4america
# 40         12             3           0       en            Albuquerque, NM
# 43         10             2           0       en                        NaN
# 65         14             2           1       en                        NaN
# 69         32             0           3       en          The Dark Alleyway
# 72         14             1           2       en  Northeastern Pennsylvania
# 77         10             0           0       en                   tanhaayi
# 79         20             4           0       en                        NaN
# 89        270            67          18       en            Ontario, Canada
# 91         12             1           0       en              Lexington, SC

# %%
w_df.loc[(w_df['likeCount']>4)&(w_df['retweetCount']>2)]
# Out:
#                      id        date  \
# 19  1627820184324001792  2023-02-20
# 40  1627819933492219904  2023-02-20
# 79  1627819294250905603  2023-02-20
# 89  1627819200835092481  2023-02-20
#
#                                            rawcontent         username  \
# 19  Winds increase late Tuesday with gusts to 40 p...    MandyBaileyWX
# 40  A very strong weather system will produce pote...          JoeKOAT
# 79  A late February weather system blowing into We...  DougPigsleyKOMO
# 89  #ONStorm #ONwx Good evening! We've got a quick...       IWeatherON
#
#     likeCount  retweetCount  replyCount language           location
# 19         10             3           0       en  Philippians 3:7-8
# 40         12             3           0       en    Albuquerque, NM
# 79         20             4           0       en                NaN
# 89        270            67          18       en    Ontario, Canada

# %% [markdown]
# # Cleaning the tweets

# %%
tweet_list = w_df.rawcontent.to_list()

# %%
def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    r = tweet.lower()
    r = profanity.censor(r)
    r = re.sub("'", "", r) # This is to avoid removing contractions in english
    r = re.sub("@[A-Za-z0-9_]+","", r) # remove mentions
    r = re.sub("#[A-Za-z0-9_]+","", r) # remove hashtags
    r = re.sub(r'http\S+', '', r)
    r = re.sub('[()!?]', ' ', r)
    r = re.sub('\[.*?\]',' ', r)
    r = re.sub("[^a-z0-9]"," ", r)
    r = r.split()
    stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
    r = [w for w in r if not w in stopwords]
    r = " ".join(word for word in r)
    return r

# %%
# w_df['cleanedTweets'], w_df['hashtags'] = zip(*w_df['rawcontent'].apply(clean_tweet))
w_df['cleanedTweets'] = w_df['rawcontent'].apply(clean_tweet) #apply cleanTweet function to the tweet
# Out:
# C:\Users\Hari\AppData\Local\Temp\ipykernel_20872\3107068827.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:

# %% [markdown]
# ## Comparing raw tweets and cleaned tweets

# %%
w_df[['rawcontent','cleanedTweets']].head(7)
# Out:
#                                           rawcontent  \
# 0  Sunset for February 20, 2023 at 05:31PM! Have ...
# 1  I guess our govt decided to stop playing whack...
# 2  Report at 00:00 \rWind:SW at av. 0mph, max gus...
# 3  I think I froze half my piercings off in this ...
# 4  Your weather for tomorrow @denverchannel https...
# 5  9 years ago today in Breckinridge, Colorado! I...
# 6  it’s the fact that it was nice this weekend an...
#
#                                        cleanedTweets
# 0  sunset february 20 2023 at 05 31pm have good n...
# 1  i guess our govt decided stop playing whack mo...
# 2  report at 00 00 wind sw at av 0mph max gust to...
# 3  i think i froze half my piercings off this col...
# 4                              your weather tomorrow
# 5  9 years ago today breckinridge colorado if onl...
# 6  it s fact that it was nice this weekend i m st...

# %%
# cleaned = [clean_tweet(tw) for tw in tweet_list]
# cleaned

# %% [markdown]
# ## copy cleaned tweet to new dataframe

# %%
# sentiment_df = w_df[['cleanedTweets']]
sentiment_df =  w_df[['cleanedTweets']].copy()

# %%
sentiment_df
# Out:
#                                          cleanedTweets
# 0    sunset february 20 2023 at 05 31pm have good n...
# 1    i guess our govt decided stop playing whack mo...
# 2    report at 00 00 wind sw at av 0mph max gust to...
# 3    i think i froze half my piercings off this col...
# 4                                your weather tomorrow
# ..                                                 ...
# 97   weather frankston australia 10 55 temp 19 1 c ...
# 98   wichita weather 61f at 5 55 pm wind wnw 1 gust...
# 99   dixon mo at 5 55 pm temp 57 4 f visibility 10 ...
# 100  wind 5 mph ene barometer 1017 71 hpa falling s...
# 101  there is fire weather watch tuesday high wind ...
#
# [102 rows x 1 columns]

# %% [markdown]
# ## import additional libraries

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import enchant
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hari\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Hari\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Spell Checker

# %%
import enchant

def spell_check(text):
    d = enchant.Dict("en_US") # initialize English dictionary
    words = text.split() # split text into words
    corrected_words = [] # initialize list to store corrected words
    for word in words:
        if d.check(word): # check if word is spelled correctly
            corrected_words.append(word) # add word to list if spelled correctly
        else:
            suggestions = d.suggest(word) # get suggestions for misspelled word
            if suggestions:
                corrected_words.append(suggestions[0]) # add first suggestion to list
            else:
                corrected_words.append(word) # add original word to list if no suggestions found
    return " ".join(corrected_words) # join corrected words back into a sentence

# %% [markdown]
# ## Tokenization

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    return tokens

# %% [markdown]
# ## Lemmatization

# %%
def lemmatize(tokens):
    lemmas = []
    for token in tokens:
        lemma = WordNetLemmatizer().lemmatize(token)
        if len(lemma) > 1 and not lemma.isnumeric():
            lemmas.append(lemma.lower())
    return lemmas

# %% [markdown]
# ## Stop words

# %%
def remove_stopwords(tokens):
    stopwords = nltk.corpus.stopwords.words('english')
    filtered_tokens = [token for token in tokens if token.lower() not in stopwords]
    return filtered_tokens

# %% [markdown]
# ## wordnet lemmatizer

# %%
def get_wordnet_pos(word):
    """
    Map POS tag to first character used by WordNetLemmatizer
    """
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
sentiment_df['cleanedTweets'] = sentiment_df['cleanedTweets'].apply(lambda x: spell_check(x))
sentiment_df['tokens'] = sentiment_df['cleanedTweets'].apply(lambda x: tokenize(x))
sentiment_df['lemmas'] = sentiment_df['tokens'].apply(lambda x: lemmatize(x))
sentiment_df['cleanedTokens'] = sentiment_df['lemmas'].apply(lambda x: remove_stopwords(x))

# %%
sentiment_df
# Out:
#                                          cleanedTweets  \
# 0    sunset February 20 2023 at 05 31pm have good n...
# 1    i guess our govt decided stop playing whack mo...
# 2    report at 00 00 wind SW at av mph max gust tod...
# 3    i think i froze half my piercings off this col...
# 4                                your weather tomorrow
# ..                                                 ...
# 97   weather franks ton Australia 10 55 temp 19 1 c...
# 98   Wichita weather 61f at 5 55 pm wind WNW 1 gust...
# 99   Dixon mo at 5 55 pm temp 57 4 f visibility 10 ...
# 100  wind 5 mph ENE barometer 1017 71 hap falling s...
# 101  there is fire weather watch Tuesday high wind ...
#
#                                                 tokens  \
# 0    [sunset, February, 20, 2023, at, 05, 31pm, hav...
# 1    [i, guess, our, govt, decided, stop, playing, ...
# 2    [report, at, 00, 00, wind, SW, at, av, mph, ma...
# 3    [i, think, i, froze, half, my, piercings, off,...
# 4                            [your, weather, tomorrow]
# ..                                                 ...
# 97   [weather, franks, ton, Australia, 10, 55, temp...
# 98   [Wichita, weather, 61f, at, 5, 55, pm, wind, W...
# 99   [Dixon, mo, at, 5, 55, pm, temp, 57, 4, f, vis...
# 100  [wind, 5, mph, ENE, barometer, 1017, 71, hap, ...
# 101  [there, is, fire, weather, watch, Tuesday, hig...
#
#                                                 lemmas  \
# 0      [sunset, february, at, 31pm, have, good, night]
# 1    [guess, our, govt, decided, stop, playing, wha...
# 2    [report, at, wind, sw, at, av, mph, max, gust,...
# 3    [think, froze, half, my, piercings, off, this,...
# 4                            [your, weather, tomorrow]
# ..                                                 ...
# 97   [weather, frank, ton, australia, temp, wind, 4...
# 98   [wichita, weather, 61f, at, pm, wind, wnw, gus...
# 99   [dixon, mo, at, pm, temp, visibility, mile, wi...
# 100  [wind, mph, ene, barometer, hap, falling, slow...
# 101  [there, is, fire, weather, watch, tuesday, hig...
#
#                                          cleanedTokens
# 0                [sunset, february, 31pm, good, night]
# 1    [guess, govt, decided, stop, playing, whack, m...
# 2    [report, wind, sw, av, mph, max, gust, today, ...
# 3       [think, froze, half, piercings, cold, weather]
# 4                                  [weather, tomorrow]
# ..                                                 ...
# 97   [weather, frank, ton, australia, temp, wind, 4...
# 98   [wichita, weather, 61f, pm, wind, wnw, gust, mph]
# 99   [dixon, mo, pm, temp, visibility, mile, wind, ...
# 100  [wind, mph, ene, barometer, hap, falling, slow...
# 101  [fire, weather, watch, tuesday, high, wind, wa...
#
# [102 rows x 4 columns]

# %%
import re
import matplotlib.pyplot as plt

# Define a regular expression to match numbers
num_pattern = re.compile(r'^\d+(\.\d+)?$')

# Function to check if a token is a number
def is_number(token):
    return bool(num_pattern.match(token))

# Calculate frequency distribution for cleaned tweets (excluding numbers)
cleaned_tweets_freq = FreqDist([token for token in sentiment_df['cleanedTweets'].apply(nltk.word_tokenize).sum() if not is_number(token)])

# Calculate frequency distribution for cleaned tokens (excluding numbers)
cleaned_tokens_freq = FreqDist([token for token in sentiment_df['cleanedTokens'].sum() if not is_number(token)])

# Plot the frequency distribution for cleaned tweets
plt.figure(figsize=(16,5))
cleaned_tweets_freq.plot(30, title='Top 30 Most Common Words in Cleaned Tweets (excluding numbers)')

# Plot the frequency distribution for cleaned tokens
plt.figure(figsize=(16,5))
cleaned_tokens_freq.plot(30, title='Top 30 Most Common Words in Cleaned Tokens (excluding numbers)')
# Out:
# <AxesSubplot:title={'center':'Top 30 Most Common Words in Cleaned Tokens (excluding numbers)'}, xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## Frequency Distribution

# %%
cleaned_tweets_freq.most_common(15)
# Out:
# [('weather', 69),
#  ('at', 41),
#  ('i', 33),
#  ('rain', 31),
#  ('mph', 25),
#  ('wind', 24),
#  ('is', 23),
#  ('this', 22),
#  ('it', 21),
#  ('mm', 20),
#  ('today', 17),
#  ('daily', 16),
#  ('s', 14),
#  ('c', 14),
#  ('max', 13)]

# %%
cleaned_tokens_freq.most_common(15)
# Out:
# [('weather', 69),
#  ('rain', 31),
#  ('wind', 26),
#  ('mph', 25),
#  ('mm', 20),
#  ('today', 17),
#  ('daily', 16),
#  ('temp', 14),
#  ('max', 13),
#  ('pm', 13),
#  ('gust', 12),
#  ('wa', 11),
#  ('temperature', 11),
#  ('report', 9),
#  ('humidity', 9)]

# %% [markdown]
# ## Removing Stopwords
# #### here, as we can clearly see that while printing most frequent words. I got these words such as i, s, c and so on. and they dont give any meaning. These words are called stop words and they are common words in a language that usually don't carry much meaning on their own. I am removing them using the NLTK library.

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Function to remove stop words from a tokenized list of words
def remove_stopwords(tokens):
    return [word for word in tokens if not word in stop_words]

# Apply stop word removal to cleaned tokens column
sentiment_df['cleanedTokens'] = sentiment_df['cleanedTokens'].apply(remove_stopwords)

# Calculate frequency distribution for cleaned tokens
cleaned_freq = FreqDist(sentiment_df['cleanedTokens'].sum())

# %%
# Print the 20 most common words
cleaned_freq.most_common(15)
# Out:
# [('weather', 69),
#  ('rain', 31),
#  ('wind', 26),
#  ('mph', 25),
#  ('mm', 20),
#  ('today', 17),
#  ('daily', 16),
#  ('temp', 14),
#  ('max', 13),
#  ('pm', 13),
#  ('gust', 12),
#  ('wa', 11),
#  ('temperature', 11),
#  ('report', 9),
#  ('humidity', 9)]

# %% [markdown]
# ## Performing sentiment analysis

# %%
# find subjectivity
def getSubjectivity(tweet):
    return TextBlob(' '.join(tweet)).sentiment.subjectivity

# find polarity
def getPolarity(tweet):
    return TextBlob(' '.join(tweet)).sentiment.polarity

sentiment_df['Subjectivity'] = sentiment_df['cleanedTokens'].apply(getSubjectivity)
sentiment_df['Polarity'] = sentiment_df['cleanedTokens'].apply(getPolarity)

# %%
sentiment_df.sample(10)
# Out:
#                                         cleanedTweets  \
# 68  how s everyone today haven t been online becau...
# 19  winds increase late Tuesday with gusts 40 poss...
# 51  it was great get out today after long winter s...
# 24  20 02 23 23 59 current conditions temp 8 0 hum...
# 6   it s fact that it was nice this weekend i m st...
# 78   superb image typhoon beware any weather balloons
# 72  final prediction Tuesday February 21 2023 snow...
# 36  happy presidents day AVI with new year underwa...
# 85  Invercargill weather 21 Feb 2023 at 12 55 wind...
# 40  very strong weather system will produce potent...
#
#                                                tokens  \
# 68  [how, s, everyone, today, haven, t, been, onli...
# 19  [winds, increase, late, Tuesday, with, gusts, ...
# 51  [it, was, great, get, out, today, after, long,...
# 24  [20, 02, 23, 23, 59, current, conditions, temp...
# 6   [it, s, fact, that, it, was, nice, this, weeke...
# 78  [superb, image, typhoon, beware, any, weather,...
# 72  [final, prediction, Tuesday, February, 21, 202...
# 36  [happy, presidents, day, AVI, with, new, year,...
# 85  [Invercargill, weather, 21, Feb, 2023, at, 12,...
# 40  [very, strong, weather, system, will, produce,...
#
#                                                lemmas  \
# 68  [how, everyone, today, haven, been, online, be...
# 19  [wind, increase, late, tuesday, with, gust, po...
# 51  [it, wa, great, get, out, today, after, long, ...
# 24  [current, condition, temp, humidity, pressure,...
# 6   [it, fact, that, it, wa, nice, this, weekend, ...
# 78  [superb, image, typhoon, beware, any, weather,...
# 72  [final, prediction, tuesday, february, snow, h...
# 36  [happy, president, day, avi, with, new, year, ...
# 85  [invercargill, weather, feb, at, wind, speed, ...
# 40  [very, strong, weather, system, will, produce,...
#
#                                         cleanedTokens  Subjectivity  Polarity
# 68  [everyone, today, online, admin, ha, weather, ...      0.000000  0.000000
# 19  [wind, increase, late, tuesday, gust, possible...      0.633333 -0.066667
# 51  [wa, great, get, today, long, winter, tree, on...      0.620000  0.270000
# 24  [current, condition, temp, humidity, pressure,...      0.700000  0.050000
# 6   [fact, wa, nice, weekend, stuck, going, back, ...      0.500000  0.300000
# 78  [superb, image, typhoon, beware, weather, ball...      1.000000  1.000000
# 72  [final, prediction, tuesday, february, snow, h...      0.666667  0.020833
# 36  [happy, president, day, avi, new, year, underw...      0.713636  0.484091
# 85  [invercargill, weather, feb, wind, speed, kph,...      0.000000  0.000000
# 40  [strong, weather, system, produce, potentially...      0.720635  0.215873

# %% [markdown]
# ## tweet emotion whether negative, positive or neutral

# %%
def getEmotion(value):
    if value<0:
        return 'Negative'
    elif value ==0:
        return 'Neutral'
    else:
        return 'Positive'
    
sentiment_df['Emotion'] = sentiment_df['Polarity'].apply(getEmotion)

# %%
sentiment_df
# Out:
#                                          cleanedTweets  \
# 0    sunset February 20 2023 at 05 31pm have good n...
# 1    i guess our govt decided stop playing whack mo...
# 2    report at 00 00 wind SW at av mph max gust tod...
# 3    i think i froze half my piercings off this col...
# 4                                your weather tomorrow
# ..                                                 ...
# 97   weather franks ton Australia 10 55 temp 19 1 c...
# 98   Wichita weather 61f at 5 55 pm wind WNW 1 gust...
# 99   Dixon mo at 5 55 pm temp 57 4 f visibility 10 ...
# 100  wind 5 mph ENE barometer 1017 71 hap falling s...
# 101  there is fire weather watch Tuesday high wind ...
#
#                                                 tokens  \
# 0    [sunset, February, 20, 2023, at, 05, 31pm, hav...
# 1    [i, guess, our, govt, decided, stop, playing, ...
# 2    [report, at, 00, 00, wind, SW, at, av, mph, ma...
# 3    [i, think, i, froze, half, my, piercings, off,...
# 4                            [your, weather, tomorrow]
# ..                                                 ...
# 97   [weather, franks, ton, Australia, 10, 55, temp...
# 98   [Wichita, weather, 61f, at, 5, 55, pm, wind, W...
# 99   [Dixon, mo, at, 5, 55, pm, temp, 57, 4, f, vis...
# 100  [wind, 5, mph, ENE, barometer, 1017, 71, hap, ...
# 101  [there, is, fire, weather, watch, Tuesday, hig...
#
#                                                 lemmas  \
# 0      [sunset, february, at, 31pm, have, good, night]
# 1    [guess, our, govt, decided, stop, playing, wha...
# 2    [report, at, wind, sw, at, av, mph, max, gust,...
# 3    [think, froze, half, my, piercings, off, this,...
# 4                            [your, weather, tomorrow]
# ..                                                 ...
# 97   [weather, frank, ton, australia, temp, wind, 4...
# 98   [wichita, weather, 61f, at, pm, wind, wnw, gus...
# 99   [dixon, mo, at, pm, temp, visibility, mile, wi...
# 100  [wind, mph, ene, barometer, hap, falling, slow...
# 101  [there, is, fire, weather, watch, tuesday, hig...
#
#                                          cleanedTokens  Subjectivity  \
# 0                [sunset, february, 31pm, good, night]      0.600000
# 1    [guess, govt, decided, stop, playing, whack, m...      0.000000
# 2    [report, wind, sw, av, mph, max, gust, today, ...      0.633333
# 3       [think, froze, half, piercings, cold, weather]      0.583333
# 4                                  [weather, tomorrow]      0.000000
# ..                                                 ...           ...
# 97   [weather, frank, ton, australia, temp, wind, 4...      0.577778
# 98   [wichita, weather, 61f, pm, wind, wnw, gust, mph]      0.000000
# 99   [dixon, mo, pm, temp, visibility, mile, wind, ...      0.000000
# 100  [wind, mph, ene, barometer, hap, falling, slow...      0.400000
# 101  [fire, weather, watch, tuesday, high, wind, wa...      0.540000
#
#      Polarity   Emotion
# 0    0.700000  Positive
# 1    0.000000   Neutral
# 2   -0.162500  Negative
# 3   -0.383333  Negative
# 4    0.000000   Neutral
# ..        ...       ...
# 97   0.166667  Positive
# 98   0.000000   Neutral
# 99   0.000000   Neutral
# 100 -0.300000  Negative
# 101  0.160000  Positive
#
# [102 rows x 7 columns]

# %% [markdown]
# ## Performing EDA after sentiment analysis

# %%
sentiment_df['Emotion'].value_counts()
# Out:
# Positive    47
# Neutral     37
# Negative    18
# Name: Emotion, dtype: int64

# %%
sns.countplot(x ='Emotion', data = sentiment_df)
# Out:
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
fig = plt.figure(figsize=(7,7))
colors = ('green', 'orange', 'silver')
wp = {'linewidth':2, 'edgecolor': 'black'}
tags = sentiment_df['Emotion'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind ='pie', autopct='%1.1f%%', shadow=True, colors=colors, 
         startangle=90, wedgeprops=wp, explode=explode, label='')
plt.title('Distribution of polarity')
# Out:
# Text(0.5, 1.0, 'Distribution of polarity')

# %%
sentiment_df.to_csv("sentiment.csv",index = False)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=100,
        max_font_size=35, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(sentiment_df['cleanedTokens'])
